# %%
# %run convert.py adoptedLevels60Co.csv Co60.ags
# Out:
# adoptedLevels60Co.csv:1
# 	E(level)(keV) is column 0
# 	Jπ(level) is column 2
#
# adoptedLevels60Co.csv:2
# 	E(level)(keV) has token "0.0"
# 	Jπ(level) has token "5+"
# adoptedLevels60Co.csv:2
# 	String "0.0" split in fewer than 2 tokens
#
# adoptedLevels60Co.csv:3
# 	E(level)(keV) has token "58.59 1"
# 	Jπ(level) has token "2+"
#
# adoptedLevels60Co.csv:4
# 	E(level)(keV) has token "277.20 2"
# 	Jπ(level) has token "4+"
#
# adoptedLevels60Co.csv:5
# 	E(level)(keV) has token "288.40 2"
# 	Jπ(level) has token "3+"
#
# adoptedLevels60Co.csv:6
# 	E(level)(keV) has token "435.71 4"
# 	Jπ(level) has token "5+"
#
# adoptedLevels60Co.csv:7
# 	E(level)(keV) has token "506.20 3"
# 	Jπ(level) has token "3+"
#
# adoptedLevels60Co.csv:8
# 	E(level)(keV) has token "542.82 2"
# 	Jπ(level) has token "2+"
#
# adoptedLevels60Co.csv:9
# 	E(level)(keV) has token "614.55 2"
# 	Jπ(level) has token "3+"
#
# adoptedLevels60Co.csv:10
# 	E(level)(keV) has token "738.80 2"
# 	Jπ(level) has token "1+"
#
# ...

# %%
# %run aceconvert.py adoptedLevels60Co.csv Co60-1.ags
# Out:
# adoptedLevels60Co.csv:1
# 	E(level)(keV) is column 0
# 	Jπ(level) is column 2
#
# adoptedLevels60Co.csv:2
# 	E(level)(keV) has token "0.00 0"
# 	Jπ(level) has token "5+"
#
# adoptedLevels60Co.csv:3
# 	E(level)(keV) has token "58.59 1"
# 	Jπ(level) has token "2+"
#
# adoptedLevels60Co.csv:4
# 	E(level)(keV) has token "277.20 2"
# 	Jπ(level) has token "4+"
#
# adoptedLevels60Co.csv:5
# 	E(level)(keV) has token "288.40 2"
# 	Jπ(level) has token "3+"
#
# adoptedLevels60Co.csv:6
# 	E(level)(keV) has token "435.71 4"
# 	Jπ(level) has token "5+"
#
# adoptedLevels60Co.csv:7
# 	E(level)(keV) has token "506.20 3"
# 	Jπ(level) has token "3+"
#
# adoptedLevels60Co.csv:8
# 	E(level)(keV) has token "542.82 2"
# 	Jπ(level) has token "2+"
#
# adoptedLevels60Co.csv:9
# 	E(level)(keV) has token "614.55 2"
# 	Jπ(level) has token "3+"
#
# adoptedLevels60Co.csv:10
# 	E(level)(keV) has token "738.80 2"
# 	Jπ(level) has token "1+"
#
# adoptedLevels60Co.csv:11
# 	E(level)(keV) has token "785.71 1"
# ...

# %%
# %run convert.py Co60_HelperScript.csv Co60Helper_1.ags
# Out:
# Co60_HelperScript.csv:1
# 	E(level)(keV) is column 0
# 	JPi(level) is column 1
# 	E()(keV) is column 2
# 	I() is column 3
# 	M() is column 4
#
# Co60_HelperScript.csv:2
# 	E(level)(keV) has token "0.00 0"
# 	JPi(level) has token "5+"
# 	E()(keV) has token "0.00 0"
# 	I() has token "0"
# 	M() has token "E 2"
# 	Intensity string "0" split into <2 tokens
#
# Co60_HelperScript.csv:3
# 	E(level)(keV) has token "58.59 1"
# 	JPi(level) has token "2+"
# 	E()(keV) has token "58.603 7"
# 	I() has token "100 1"
# 	M() has token "E 4"
#
# Co60_HelperScript.csv:4
# 	E(level)(keV) has token "277.20 2"
# 	JPi(level) has token "4+"
# 	E()(keV) has token "277.08 3"
# 	I() has token "100 1"
# 	M() has token "E 2"
#
# Co60_HelperScript.csv:5
# 	E(level)(keV) has token "288.40 2"
# 	JPi(level) has token "3+"
# 	E()(keV) has token "229.72 4"
# 	I() has token "100 1"
# 	M() has token "E 2"
#
# Co60_HelperScript.csv:6
# 	E(level)(keV) has token "435.71 4"
# 	JPi(level) has token "5+"
# ...

# %%
# %run convert.py 173Hf_HelperScript-1.csv Hf173Helper_1.ags
# Out:
# 173Hf_HelperScript-1.csv:2
# 	E(level)(keV) has token "0"
# 	JPi(level) has token "1/2-"
# 	E()(keV) has token "nan"
# 	I() has token "nan"
# 	M() has token "E 2"
#
# 173Hf_HelperScript-1.csv:3
# 	E(level)(keV) has token "69.73 4"
# 	JPi(level) has token "3/2-"
# 	E()(keV) has token "69.70 5"
# 	I() has token "100 0"
# 	M() has token "E 2"
#
# 173Hf_HelperScript-1.csv:4
# 	E(level)(keV) has token "81.49 5"
# 	JPi(level) has token "5/2-"
# 	E()(keV) has token "11.9 2"
# 	I() has token "100 0"
# 	M() has token "E 2"
#
# 173Hf_HelperScript-1.csv:5
# 	E(level)(keV) has token "81.49 5"
# 	JPi(level) has token "5/2-"
# 	E()(keV) has token "81.5 1"
# 	I() has token "100 0"
# 	M() has token "E 2"
#
# 173Hf_HelperScript-1.csv:6
# 	E(level)(keV) has token "107.16 5"
# 	JPi(level) has token "5/2-"
# 	E()(keV) has token "25.70 5"
# 	I() has token "11 3"
# 	M() has token "E 2"
#
# 173Hf_HelperScript-1.csv:7
# 	E(level)(keV) has token "107.16 5"
# 	JPi(level) has token "5/2-"
# ...

# %%
# %run convert.py Hf166_HelperScript.csv Hf166.ags
# Out:
# Hf166_HelperScript.csv:2
# 	E(level)(keV) has token "0"
# 	JPi(level) has token "0+"
# 	E()(keV) has token "nan"
# 	I() has token "nan"
# 	M() has token "E 2"
#
# Hf166_HelperScript.csv:3
# 	E(level)(keV) has token "158.64 5"
# 	JPi(level) has token "2+"
# 	E()(keV) has token "158.64 4"
# 	I() has token "100 0"
# 	M() has token "E 2"
#
# Hf166_HelperScript.csv:4
# 	E(level)(keV) has token "470.46 6"
# 	JPi(level) has token "4+"
# 	E()(keV) has token "311.87 5"
# 	I() has token "100 0"
# 	M() has token "E 2"
#
# Hf166_HelperScript.csv:5
# 	E(level)(keV) has token "809.96 6"
# 	JPi(level) has token "(2+)"
# 	E()(keV) has token "651.26 5"
# 	I() has token "93.6 20"
# 	M() has token "E 2"
# 	[Invalid Level] JPi string "(2+)" not proper format
#
# Hf166_HelperScript.csv:6
# 	E(level)(keV) has token "809.96 6"
# 	JPi(level) has token "(2+)"
# 	E()(keV) has token "651.26 5"
# 	I() has token "100 9"
# 	M() has token "E 2"
# 	[Invalid Level] JPi string "(2+)" not proper format
#
# ...

# %%
# %run convert.py Hf173_HelperScript.csv Hf173.ags
# Out:
# Hf173_HelperScript.csv:2
# 	E(level)(keV) has token "0"
# 	JPi(level) has token "1/2-"
# 	E()(keV) has token "nan"
# 	I() has token "nan"
# 	M() has token "E 2"
#
# Hf173_HelperScript.csv:3
# 	E(level)(keV) has token "69.73 4"
# 	JPi(level) has token "3/2-"
# 	E()(keV) has token "69.70 5"
# 	I() has token "100 0"
# 	M() has token "E 2"
#
# Hf173_HelperScript.csv:4
# 	E(level)(keV) has token "81.49 5"
# 	JPi(level) has token "5/2-"
# 	E()(keV) has token "11.9 2"
# 	I() has token "100 0"
# 	M() has token "E 2"
#
# Hf173_HelperScript.csv:5
# 	E(level)(keV) has token "81.49 5"
# 	JPi(level) has token "5/2-"
# 	E()(keV) has token "81.5 1"
# 	I() has token "100 0"
# 	M() has token "E 2"
#
# Hf173_HelperScript.csv:6
# 	E(level)(keV) has token "107.16 5"
# 	JPi(level) has token "5/2-"
# 	E()(keV) has token "25.70 5"
# 	I() has token "11 3"
# 	M() has token "E 2"
#
# Hf173_HelperScript.csv:7
# 	E(level)(keV) has token "107.16 5"
# 	JPi(level) has token "5/2-"
# 	E()(keV) has token "25.70 5"
# ...

# %%
# %run convert.py Co60_HelperScript.csv Co60Helper.ags
# Out:
# Error on line 1: 'Header "BandName" not found in line 1'
# [HEADER] Failed to extract BandNum or Z: '>' not supported between instances of 'NoneType' and 'NoneType'
# [HEADER] Final values - Z: 0, Nlevels: 0, Ngammas: 0, Nbands: 0
# Writing Band section...
# [DEBUG] Parsed header: ['E(level)(keV)', 'JPi(level)', 'E()(keV)', 'I()', 'M()']
# Error while writing Band section: 'BandName or BandNum missing'
